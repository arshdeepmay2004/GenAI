# %%
import pandas as pd
data=pd.read_csv('Housing.csv')
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    str
#  6   guestroom         545 non-null    str
#  7   basement          545 non-null    str
#  8   hotwaterheating   545 non-null    str
#  9   airconditioning   545 non-null    str
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    str
#  12  furnishingstatus  545 non-null    str
# dtypes: int64(6), str(7)
# memory usage: 55.5 KB

# %%
data.mainroad.value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
data.mainroad=data.mainroad.map({"yes":1,"no":0})
data.guestroom=data.guestroom.map({"yes":1,"no":0})
data.basement=data.basement.map({"yes":1,"no":0})
data.hotwaterheating=data.hotwaterheating.map({"yes":1,"no":0})
data.airconditioning=data.airconditioning.map({"yes":1,"no":0})
data.prefarea=data.prefarea.map({"yes":1,"no":0})
data.furnishingstatus=data.furnishingstatus.map({"furnished":1,"unfurnished":0,"semi-furnished":2})

# %%
data.furnishingstatus.value_counts()
data.loc[:,"furnishingstatus"].value_counts()
# Out:
# furnishingstatus
# 2    227
# 0    178
# 1    140
# Name: count, dtype: int64

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
x= data.iloc[:,1:]
y=data.loc[:,:"price"]
y
# option 2:
# a = data.drop("price",axis = 1)
# a
# b = data.price
# b
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
x_train
# Out:
#       area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 175   9800         4          2        2         1          1         0
# 25    6540         4          2        2         1          1         1
# 253   3520         2          1        2         1          0         0
# 257   8250         3          1        1         1          0         0
# 431   3180         4          1        2         1          0         1
# ..     ...       ...        ...      ...       ...        ...       ...
# 369   3600         2          1        1         1          0         0
# 320   4320         3          1        2         1          0         0
# 527   1836         2          1        1         0          0         1
# 125  15600         3          1        1         1          0         0
# 265   2880         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 175                0                0        2         0                 2
# 25                 0                1        2         1                 1
# 253                0                0        0         1                 1
# 257                0                0        0         0                 1
# 431                0                1        0         0                 0
# ..               ...              ...      ...       ...               ...
# 369                0                0        0         0                 1
# 320                0                0        2         1                 1
# 527                0                0        0         0                 2
# 125                0                1        2         0                 2
# 265                0                0        0         1                 2
#
# [381 rows x 12 columns]

# %%
y_train
# Out:
#        price
# 175  5250000
# 25   8540000
# 253  4515000
# 257  4480000
# 431  3290000
# ..       ...
# 369  3675000
# 320  4060000
# 527  2275000
# 125  5943000
# 265  4403000
#
# [381 rows x 1 columns]

# %%
y_test
# Out:
#        price
# 482  2940000
# 314  4095000
# 383  3570000
# 487  2870000
# 43   7700000
# ..       ...
# 26   8463000
# 212  4893000
# 282  4270000
# 226  4690000
# 99   6265000
#
# [164 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([[ 2643688.64149161],
#        [ 3859348.78874555],
#        [ 5730627.48102526],
#        [ 3827438.52424499],
#        [ 6766875.41577844],
#        [ 6730710.32316336],
#        [ 3596564.77481856],
#        [ 3075533.50443743],
#        [ 5520441.06589971],
#        [ 3125199.02746381],
#        [ 4829932.40955298],
#        [ 2136891.82159399],
#        [ 4371266.62091605],
#        [ 4724570.25010246],
#        [ 6543164.5658446 ],
#        [ 2406068.91604462],
#        [ 7147914.70068885],
#        [ 6585910.36772905],
#        [ 5282810.55591119],
#        [ 4470022.24115468],
#        [ 3572831.96640045],
#        [ 4802765.05517657],
#        [ 4384853.53275358],
#        [ 3080593.37962398],
#        [ 7353609.12149625],
#        [ 4970692.55054916],
#        [ 5559806.32251608],
#        [ 8536726.51606993],
#        [ 6276284.40937208],
#        [ 3600647.93736464],
#        [ 3691758.09128799],
#        [ 6968930.46564468],
#        [ 6492962.34119626],
#        [ 4458719.71605272],
#        [ 5878889.43826273],
#        [ 4635581.71277682],
#        [ 3667981.71713986],
#        [ 3375466.46809012],
#        [ 3609252.364254  ],
#        [ 6453598.59552251],
#        [ 7617689.53919442],
#        [ 3018727.37037116],
#        [ 3899630.12642644],
#        [ 4455821.04574248],
#        [ 3049935.16303915],
#        [ 8306707.61333383],
#        [ 6625053.05827095],
#        [ 4032359.93151222],
#        [ 5865009.95235097],
#        [ 5815779.55373835]])

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score , mean_squared_error
r2_score(y_test,y_pred)
# Out:
# 0.7359925296419539

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 769757564338.5887

# %%
import joblib
joblib.dump(model,'house.pkl')
# Out:
# ['house.pkl']

# %%
import joblib
house =joblib.load('house.pkl')
house.predict([[9960,4,2,3,1,0,1,0,1,2,1,0]])
# Out:
# c:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[9027238.46325902]])

# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.1-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.23-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in C:\Users\arshd\AppData\Roaming\Python\Python314\site-packages (from kagglehub) (26.1)
# Collecting pyyaml (from kagglehub)
#   Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from kagglehub) (2.33.1)
# Collecting tqdm (from kagglehub)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting protobuf (from kagglesdk<1.0,>=0.1.22->kagglehub)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->kagglehub) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->kagglehub) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->kagglehub) (2026.4.22)
# Requirement already satisfied: colorama in C:\Users\arshd\AppData\Roaming\Python\Python314\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.1-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.23-py3-none-any.whl (217 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading pyyaml-6.0.3-cp314-cp314-win_amd64.whl (156 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, pyyaml, protobuf, kagglesdk, kagglehub
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [pyyaml]
#    -------- ------------------------------- 1/5 [pyyaml]
#    -------- ------------------------------- 1/5 [pyyaml]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ---------------- ----------------------- 2/5 [protobuf]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    ------------------------ --------------- 3/5 [kagglesdk]
#    -------------------------------- ------- 4/5 [kagglehub]
#    -------------------------------- ------- 4/5 [kagglehub]
#    -------------------------------- ------- 4/5 [kagglehub]
#    -------------------------------- ------- 4/5 [kagglehub]
#    ---------------------------------------- 5/5 [kagglehub]
#
# Successfully installed kagglehub-1.0.1 kagglesdk-0.1.23 protobuf-7.34.1 pyyaml-6.0.3 tqdm-4.67.3
#   WARNING: The script tqdm.exe is installed in 'C:\Users\arshd\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
